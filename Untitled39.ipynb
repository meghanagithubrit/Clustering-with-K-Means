# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanagithubrit/Clustering-with-K-Means/blob/main/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
dataset.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
dataset.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
np.median(dataset["housing_median_age"])
# Out:
# np.float64(29.0)

# %%
dataset["population"].mean()
# Out:
# np.float64(1429.5739411764705)

# %%
dataset["housing_median_age"].median()
# Out:
# 29.0

# %%
dataset["population"].mean()
# Out:
# np.float64(1429.5739411764705)

# %%
np.mean(dataset["population"])
# Out:
# np.float64(1429.5739411764705)

# %%
sns.histplot(x= "population",data=dataset)
plt.show()

# %%
sns.histplot(x= "total_rooms" , data=dataset)
plt.show()

# %%
sns.barplot(x="population",y= "housing_median_age",data=dataset)
plt.show()

# %%
sns.histplot(x="housing_median_age",data=dataset,bins=[i for i in range(0,60,10)])
mn = dataset["housing_median_age"].mean()
plt.axvline(x=mn, color='red', linestyle='--', label=f'Mean: {mn:.2f}')
plt.legend()
plt.show()

# %%
dataset["population"].mode()
# Out:
# 0    891.0
# Name: population, dtype: float64

# %%
dataset["housing_median_age"].value_counts()
# Out:
# housing_median_age
# 52.0    1052
# 36.0     715
# 35.0     692
# 16.0     635
# 17.0     576
# 34.0     567
# 33.0     513
# 26.0     503
# 18.0     478
# 25.0     461
# 32.0     458
# 37.0     437
# 15.0     416
# 19.0     412
# 28.0     400
# 27.0     397
# 24.0     389
# 31.0     384
# 30.0     384
# 20.0     383
# 23.0     382
# 29.0     374
# 21.0     373
# 14.0     347
# 22.0     323
# 38.0     318
# 42.0     308
# 39.0     302
# 44.0     296
# 43.0     286
# 13.0     249
# 40.0     249
# 45.0     235
# 41.0     232
# 10.0     226
# 11.0     208
# 5.0      199
# 46.0     196
# 12.0     192
# 8.0      178
# 47.0     175
# 9.0      172
# 4.0      161
# 7.0      151
# 48.0     135
# 6.0      129
# 50.0     112
# 49.0     111
# 2.0       49
# 3.0       46
# 51.0      32
# 1.0        2
# Name: count, dtype: int64

# %%
dataset["housing_median_age"].mode()
# Out:
# 0    52.0
# Name: housing_median_age, dtype: float64

# %%
sns.histplot(x="housing_median_age",data=dataset,bins=[i for i in range(0,60,10)])
md = dataset["housing_median_age"].median()
plt.axvline(x=mn, color='red', linestyle='--', label=f'Median: {mn:.2f}')
plt.legend()
plt.show()

# %%
sns.histplot(x="housing_median_age",data=dataset,bins=[i for i in range(0,60,10)])
mo = dataset["housing_median_age"].mode()
plt.axvline(x=mn, color='red', linestyle='--', label=f'Mode: {mn:.2f}')
plt.axvline(x=mn, color='blue', linestyle='--', label=f'Mode: {mn:.2f}')
plt.axvline(x=mn, color='green', linestyle='--', label=f'Mode: {mn:.2f}')
plt.legend()
plt.show()
