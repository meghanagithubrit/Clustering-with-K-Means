# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanagithubrit/Clustering-with-K-Means/blob/main/task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/test.csv")

# %%
dataset.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dataset["Age"].fillna(dataset["Age"].mean(),inplace=True)

# %%
dataset["Age"]
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
np.percentile(dataset["Age"],25)
# Out:
# np.float64(23.0)

# %%
np.percentile(dataset["Age"],34)
# Out:
# np.float64(25.78)

# %%
dataset["Age"].max()
# Out:
# 76.0

# %%
dataset["Age"].median()
# Out:
# 30.272590361445783

# %%
dataset.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   12.634534    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   23.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   30.272590    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   35.750000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
sns.boxplot(dataset["Age"])
plt.show()

# %%
sns.boxplot(x="Age",data=dataset)
plt.show()

# %%
dataset.tail(3)
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket     Fare Cabin Embarked
# 415      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416      0              359309   8.0500   NaN        S
# 417      1                2668  22.3583   NaN        C

# %%
dataset["Age"].mean()
# Out:
# np.float64(30.272590361445783)

# %%
sns.boxplot(x="Fare",data=dataset)
plt.show()

# %%
sec_a = np.array([79,78,98,87,76,89,87.44])
sec_b = np.array([48,87,98,67,54,65,34,56])
no = np.array([1,2,3,4,5,6])

# %%
dataset["Fare"].mean()
# Out:
# np.float64(35.627188489208635)

# %%
dataset["Fare"].median()
# Out:
# 14.4542

# %%
dataset["Fare"].mode()
# Out:
# 0    7.75
# Name: Fare, dtype: float64

# %%
std = np.std(dataset["Fare"])
std
# Out:
# 55.84050047954103

# %%
sns.histplot(dataset["Fare"])
plt.show()

# %%
sns.histplot(dataset["Age"])
plt.show()

# %%
sns = sns.histplot(dataset["Fare"])
plt.show()

# %%
dataset.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
plt.figure(figsize=(8,7))
plt.scatter(sec_a[:len(no)],no,label="sec_A")
plt.scatter(sec_b[:len(no)], no,label="sec_B", color="red")
plt.legend()
plt.show()

# %%
mean = np.mean(sec_b)
mean
# Out:
# np.float64(63.625)

# %%
median = np.median(sec_b)
median
# Out:
# np.float64(60.5)

# %%
np.std(sec_a),np.std(sec_b)
# Out:
# (np.float64(7.1804178151414), np.float64(19.4096464419113))

# %%
std = np.std(sec_a)
std
# Out:
# np.float64(7.1804178151414)
